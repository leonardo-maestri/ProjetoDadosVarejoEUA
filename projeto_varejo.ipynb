# %% [markdown]
# # <font color='blue'>Data Science Academy</font>
#
# ## <font color='blue'>Fundamentos de Linguagem Python Para Análise de Dados e Data Science</font>
#
# ## <font color='blue'>Projeto 2</font>
#
# ## <font color='blue'>Análise Exploratória de Dados em Linguagem Python Para a Área de Varejo</font>
#
# ## <font color='blue'>Os dados Já estão tratados, sem duplicidades, ou valores ausentes</font>
#
# ## <font color='blue'>Projeto realizado no mês 07/2024</font>

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sea
import datetime as dt

# %% [markdown]
# ## Carregando os Dados

# %%
# Carrega o dataset
df = pd.read_csv('dados/dataset.csv')

# %%
# Shape
df.shape
# Out:
# (9700, 11)

# %%
# Amostra dos dados
df.head(10)
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 5  CA-2015-115812  09/06/2015   BH-11710   Consumer  United States
# 6  CA-2015-115812  09/06/2015   BH-11710   Consumer  United States
# 7  CA-2015-115812  09/06/2015   BH-11710   Consumer  United States
# 8  CA-2015-115812  09/06/2015   BH-11710   Consumer  United States
# 9  CA-2015-115812  09/06/2015   BH-11710   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# ...

# %% [markdown]
# ## Análise Exploratória

# %%
# Colunas do conjunto de dados
df.columns
# Out:
# Index(['ID_Pedido', 'Data_Pedido', 'ID_Cliente', 'Segmento', 'Pais', 'Cidade',
#        'Estado', 'ID_Produto', 'Categoria', 'SubCategoria', 'Valor_Venda'],
#       dtype='object')

# %%
# Verificando o tipo de dado de cada coluna
df.dtypes
# Out:
# ID_Pedido        object
# Data_Pedido      object
# ID_Cliente       object
# Segmento         object
# Pais             object
# Cidade           object
# Estado           object
# ID_Produto       object
# Categoria        object
# SubCategoria     object
# Valor_Venda     float64
# dtype: object

# %%
# Resumo estatístico da coluna com o valor de venda
df['Valor_Venda'].describe()
# Out:
# count     9700.000000
# mean       230.469892
# std        627.504252
# min          0.444000
# 25%         17.248000
# 50%         54.272000
# 75%        209.932500
# max      22638.480000
# Name: Valor_Venda, dtype: float64

# %%
# Verificando se há registros duplicados
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID_Pedido, Data_Pedido, ID_Cliente, Segmento, Pais, Cidade, Estado, ID_Produto, Categoria, SubCategoria, Valor_Venda]
# Index: []

# %%
# Verificando de há valores ausentes
df_dsa.isnull().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Cidade          0
# Estado          0
# ID_Produto      0
# Categoria       0
# SubCategoria    0
# Valor_Venda     0
# dtype: int64

# %% [markdown]
# ## Pergunta de Negócio 1:
#
# ### Qual Cidade com Maior Valor de Venda de Produtos da Categoria 'Office Supplies'?

# %%
# filtrando categoria para 'Office Supplies'
df1 = df[(df.Categoria == 'Office Supplies')]

# agrupando por cidade e calculando o total das vendas
df1_total = df1.groupby('Cidade')['Valor_Venda'].sum()
    
# encontrando a cidade com maior valor de venda
cidade_maior_venda = df1_total.idxmax()
print("Cidade com maior valor de venda para 'Office Supplies':", cidade_maior_venda)
# Out:
# Cidade com maior valor de venda para 'Office Supplies': New York City

# %% [markdown]
# ## Pergunta de Negócio 2:
#
# ### Qual o Total de Vendas Por Data do Pedido?
#
# Demonstre o resultado através de um gráfico de barras.

# %%
# total de vendas por data de pedido
df2 = df.groupby('Data_Pedido')['Valor_Venda'].sum()

# montando o gráfico com o plot do pandas
plt.figure(figsize = (20,6))
df2.plot(x = 'Data_Pedido', y = 'Valor_Venda', color = 'blue')
plt.title('Total de Vendas por Data do Pedido')
plt.show()

# mostrando as dez primeiras linhas da tabela
df2.head(10)
# Out:
# Data_Pedido
# 2015-01-03      16.448
# 2015-01-04     288.060
# 2015-01-05      19.536
# 2015-01-06    4407.100
# 2015-01-07      87.158
# 2015-01-09      40.544
# 2015-01-10      54.830
# 2015-01-11       9.940
# 2015-01-13    3553.795
# 2015-01-14      61.960
# Name: Valor_Venda, dtype: float64

# %% [markdown]
# ## Pergunta de Negócio 3:
#
# ### Qual o Total de Vendas por Estado?
#
# Demonstre o resultado através de um gráfico de barras.

# %%
# total de vendas por estado
df3 = df.groupby('Estado')['Valor_Venda'].sum().reset_index()


# montando o gráfico com o plot do seaborn
plt.figure(figsize = (16,6))
sea.barplot(data = df3,
            y = 'Valor_Venda',
            x = 'Estado').set(title = 'Vendas Por Estado')
plt.xticks(rotation = 80)
plt.show()

#monstrando a tabela
df3.head(10)
# Out:
#                  Estado  Valor_Venda
# 0               Alabama   19510.6400
# 1               Arizona   35272.6570
# 2              Arkansas   11673.8300
# 3            California  442927.0975
# 4              Colorado   31841.5980
# 5           Connecticut   13366.7370
# 6              Delaware   26452.5890
# 7  District of Columbia    2865.0200
# 8               Florida   88043.7000
# 9               Georgia   48083.1600

# %% [markdown]
# ## Pergunta de Negócio 4:
#
# ### Quais São as 10 Cidades com Maior Total de Vendas?
#
# Demonstre o resultado através de um gráfico de barras horizontal.

# %%
df4 = df.groupby('Cidade')['Valor_Venda'].sum()

top10cidades = df4.sort_values(ascending=False).head(10 )

# Plotar o gráfico de barras horizontais
plt.figure(figsize=(10, 6))
top10cidades.plot(kind='barh', color='skyblue')
plt.xlabel('Valor de Vendas')
plt.ylabel('Cidade')
plt.title('Top 10 Cidades com Maiores Vendas')
plt.gca().invert_yaxis()  # Inverter a ordem das cidades para a maior estar no topo
plt.show()

# %% [markdown]
# ## Pergunta de Negócio 5:
#
# ### Qual Segmento Teve o Maior Total de Vendas?
#
# Demonstre o resultado através de um gráfico de pizza.

# %%
df5 = df.groupby('Segmento')['Valor_Venda'].sum().reset_index().sort_values(by= 'Valor_Venda', ascending = False)

# Função para converter os dados em valor absoluto pq estão em notação cientifica 
def autopct_format(values): 
    def my_format(pct): 
        total = sum(values) 
        val = int(round(pct * total / 100.0))
        return ' $ {v:d}'.format(v = val)
    return my_format

df5.head()
# Out:
#       Segmento   Valor_Venda
# 0     Consumer  1.133834e+06
# 1    Corporate  6.792322e+05
# 2  Home Office  4.224914e+05

# %%
# plot gráfico em pizza

# Tamanho da figura
plt.figure(figsize = (16, 6))

# Gráfico de pizza
plt.pie(df5['Valor_Venda'], 
        labels = df5['Segmento'],
        autopct = autopct_format(df5['Valor_Venda']), # usando a função pra converter os valores das vendas
        startangle = 90)

# Limpa o círculo central
centre_circle = plt.Circle((0, 0), 0.82, fc = 'white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Labels e anotações
plt.annotate(text = 'Total de Vendas: ' + '$ ' + str(int(sum(df5['Valor_Venda']))), xy = (-0.25, 0))
plt.title('Total de Vendas Por Segmento')
plt.show()

# %% [markdown]
# ## Pergunta de Negócio 6 :
#
# ### Qual o Total de Vendas Por Segmento e Por Ano?

# %%
df.head() 
# convertendo a coluna Data_Pedido pra datetime
df['Data_Pedido'] = pd.to_datetime(df['Data_Pedido'], format='%d/%m/%Y')
#incluindo a coluna 'ano' com os dados do df
df['Ano'] = df['Data_Pedido'].dt.year

#groupby com ano, segmento  e total de vendas 
df6 = df.groupby(['Ano','Segmento'])['Valor_Venda'].sum()

df6
# Out:
# Ano   Segmento
# 2015  Consumer       256719.9166
#       Corporate      125819.5957
#       Home Office     88229.0878
# 2016  Consumer       265295.2593
#       Corporate      114643.1229
#       Home Office     74134.1332
# 2017  Consumer       288459.5572
#       Corporate      203266.7398
#       Home Office    103639.6270
# 2018  Consumer       323359.6019
#       Corporate      235502.7284
#       Home Office    156488.5849
# Name: Valor_Venda, dtype: float64

# %% [markdown]
# ## Pergunta de Negócio 7 :
#
# Os gestores da empresa estão considerando conceder diferentes faixas de descontos e gostariam de fazer uma simulação com base na regra abaixo:
#
# - Se o Valor_Venda for maior que 1000 recebe 15% de desconto.
# - Se o Valor_Venda for menor que 1000 recebe 10% de desconto.
#
# ### Quantas Vendas Receberiam 15% de Desconto?

# %%
# função para aplicar o desconto
def desconto(valor_venda):
    if valor_venda > 1000:
        valor_venda = valor_venda * 0.85
        return valor_venda
    elif valor_venda < 1000:
        valor_venda = valor_venda * 0.90
        return valor_venda
# criando nova coluna, aplicando os valores com desconto com map
df['Vendas_Desconto'] = df['Valor_Venda'].map(desconto)

# variável pra saber a quantidade de vendas que tiveram descontos de 15%
vendas_com_desconto15 = df[df['Valor_Venda'] > 1000].shape[0]


print('A quantidade de vendas que tiveram desconto é:', vendas_com_desconto15)
df.head(5)
# Out:
# A quantidade de vendas que tiveram desconto é: 457
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda  Vendas_Desconto
# ...

# %% [markdown]
# ## Pergunta de Negócio 8 :
#
# ### Considere Que a Empresa Decida Conceder o Desconto de 15% do Item Anterior. Qual Seria a Média do Valor de Venda Antes e Depois do Desconto?

# %%
MediaSemDesc = df['Valor_Venda'].mean().round(2)
MediaComDesc = df['Vendas_Desconto'].mean().round(2)
print(f'A media sem desconto é {MediaSemDesc} e com desconto é {MediaComDesc}')
# Out:
# A media sem desconto é 230.47 e com desconto é 202.44

# %% [markdown]
# ## Pergunta de Negócio 9 (Desafio Nível Master Ninja):
#
# ### Qual o Média de Vendas Por Segmento, Por Ano e Por Mês?
#
# Demonstre o resultado através de gráfico de linha.

# %%
# criando coluna 'Mes'
df['Mes'] = df['Data_Pedido'].dt.month
# groupby
df7 = df.groupby(['Ano','Mes','Segmento'])['Valor_Venda'].agg([np.mean])

# Vamos extrair os níveis
anos = df7.index.get_level_values(0)
meses = df7.index.get_level_values(1)
segmentos = df7.index.get_level_values(2)

# Plot
plt.figure(figsize = (12, 6))
sns.set()
fig1 = sns.relplot(kind = 'line',
                   data = df7, 
                   y = 'mean', 
                   x = meses,
                   hue = segmentos, 
                   col = anos,
                   col_wrap = 2)
plt.show()

# %% [markdown]
# ## Pergunta de Negócio 10 :
#
# ### Qual o Total de Vendas Por Categoria e SubCategoria, Considerando Somente as Top 12 SubCategorias?
#
# Demonstre tudo através de um único gráfico.

# %%
#grupyby
df7 = df.groupby(['Categoria','SubCategoria'])['Valor_Venda'].sum().reset_index()
# ordenando pelas maiores vendas
df7 = df7.sort_values(by='Valor_Venda', ascending=False).head(12)

#plot
plt.figure(figsize=(10, 8))
plt.barh(df7['Categoria'] + ' - ' + df7['SubCategoria'], df7['Valor_Venda'], color='skyblue')
plt.xlabel('Valor de Venda')
plt.ylabel('Categoria - SubCategoria')
plt.title('Top 12 Combinações de Categoria e Subcategoria com Maior Valor de Venda')
plt.gca().invert_yaxis()  # Inverte a ordem das barras para a maior combinação no topo
plt.grid(True, linestyle='--', alpha=0.5)  # Adiciona grid ao gráfico

# Mostrar o gráfico
plt.show()

# %% [markdown]
# # Fim
